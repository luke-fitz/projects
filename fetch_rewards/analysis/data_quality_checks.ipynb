# %%
import pandas as pd

# %%
# Change as needed
BASE_DIR = r'C:\Users\lukef\Documents\projects\fetch_rewards'

# %%
# Define data paths
data_dir = BASE_DIR + '/data'
raw_data_dir = data_dir + '/raw'
cleansed_data_dir = data_dir + '/cleansed'

# %%
# Import data sets
dim_brands = pd.read_parquet(cleansed_data_dir + '/dim_brands.parquet')
dim_users = pd.read_parquet(cleansed_data_dir + '/dim_users.parquet')
fact_receipts = pd.read_parquet(cleansed_data_dir + '/fact_receipts.parquet')
fact_receipt_items = pd.read_parquet(cleansed_data_dir + '/fact_receipt_items.parquet')

# %% [markdown]
# # Helper functions

# %%
def basic_checks(df, column):
    """
    Performs basic checks on a DataFrame column including count of unique values and number of null or empty values.
    """
    print('\n' + '*' * 20 + '\n' + column + '\n' + '*' * 20)
    print(f"{column}: {df[column].nunique()} unique values out of {len(df)}")
    print(f"{column}: {len(df.loc[df[column].isnull() | (df[column] == '')])} null or empty values")

def id_column_checks(df, column):
    """
    Performs checks specific to ID columns: basic checks plus uniqueness check.
    """
    basic_checks(df, column)
    if df[column].nunique() == len(df):
        print(f"{column} is unique")
    else:
        print(f"{column} is not unique")

def varchar_column_checks(df, column):
    """
    Performs checks specific to varchar/string columns: basic checks plus frequency counts of values (including missing).
    """
    basic_checks(df, column)
    print(df.fillna('#Missing').groupby(column).size().sort_values(ascending=False))

def numeric_column_checks(df, column):
    """
    Performs checks specific to numeric columns: basic checks plus descriptive statistics.
    """
    basic_checks(df, column)
    print(df[column].describe())

def all_column_checks(df, column_type_dict):
    """
    Performs appropriate checks on all columns in a DataFrame, based on column types provided in a dictionary.
    """
    if 'id_columns' in column_type_dict:
        for column in column_type_dict['id_columns']:
            id_column_checks(df, column)

    if 'varchar_columns' in column_type_dict:
        for column in column_type_dict['varchar_columns']:
            varchar_column_checks(df, column)

    if 'numeric_columns' in column_type_dict:
        for column in column_type_dict['numeric_columns']:
            numeric_column_checks(df, column)

def date_order_check(df, earlier_date_column, later_date_column):
    """
    Checks for records where the later date column contains dates earlier than the earlier date column.
    """
    print(f"{sum(df[later_date_column] < df[earlier_date_column])} records with {later_date_column} before {earlier_date_column}")

def referential_integrity_check(df, column, reference_column):
    """
    Checks for orphaned values in a DataFrame column by comparing against a reference column.
    """
    print(f"{len(df.loc[~df[column].isin(reference_column)])} out of {len(df)} orphaned values of {column}")

# %% [markdown]
# # dim_brands

# %%
dim_brands.head()
# Out:
#                     brandId       barcode      categoryCode        category  \
# 0  601ac115be37ce2ead437551  511111019862            BAKING          Baking
# 1  601c5460be37ce2ead43755f  511111519928         BEVERAGES       Beverages
# 2  601ac142be37ce2ead43755d  511111819905            BAKING          Baking
# 3  601ac142be37ce2ead43755a  511111519874            BAKING          Baking
# 4  601ac142be37ce2ead43755e  511111319917  CANDY_AND_SWEETS  Candy & Sweets
#
#                       cpgId cpgRef                       name  topBrand  \
# 0  601ac114be37ce2ead437550   Cogs  test brand @1612366101024       0.0
# 1  5332f5fbe4b03c9a25efd0ba   Cogs                  Starbucks       0.0
# 2  601ac142be37ce2ead437559   Cogs  test brand @1612366146176       0.0
# 3  601ac142be37ce2ead437559   Cogs  test brand @1612366146051       0.0
# 4  5332fa12e4b03c9a25efd1e7   Cogs  test brand @1612366146827       0.0
#
#                        brandCode
# 0                           None
# 1                      STARBUCKS
# 2  TEST BRANDCODE @1612366146176
# 3  TEST BRANDCODE @1612366146051
# 4  TEST BRANDCODE @1612366146827

# %%
dim_brands_cols = {
    'id_columns': ['brandId', 'cpgId'],
    'varchar_columns': ['barcode', 'categoryCode', 'category', 'cpgRef', 'name', 'topBrand', 'brandCode']
}

all_column_checks(dim_brands, dim_brands_cols)
# Out:
# ********************
# brandId
# ********************
# brandId: 1167 unique values out of 1167
# brandId: 0 null or empty values
# brandId is unique
#
# ********************
# cpgId
# ********************
# cpgId: 196 unique values out of 1167
# cpgId: 0 null or empty values
# cpgId is not unique
#
# ********************
# barcode
# ********************
# barcode: 1160 unique values out of 1167
# barcode: 0 null or empty values
# barcode
# 511111504139    2
# 511111305125    2
# 511111704140    2
# 511111605058    2
# 511111004790    2
#                ..
# 511111303893    1
# 511111303732    1
# 511111303664    1
# 511111303503    1
# 511111919803    1
# Length: 1160, dtype: int64
#
# ********************
# categoryCode
# ********************
# categoryCode: 14 unique values out of 1167
# categoryCode: 650 null or empty values
# categoryCode
# #Missing                         650
# BAKING                           359
# CANDY_AND_SWEETS                  71
# BEER_WINE_SPIRITS                 31
# HEALTHY_AND_WELLNESS              14
# GROCERY                           11
# BABY                               7
# CLEANING_AND_HOME_IMPROVEMENT      6
# BREAD_AND_BAKERY                   5
# DAIRY_AND_REFRIGERATED             5
# PERSONAL_CARE                      4
# BEVERAGES                          1
# FROZEN                             1
# MAGAZINES                          1
# OUTDOOR                            1
# dtype: int64
#
# ********************
# category
# ********************
# category: 23 unique values out of 1167
# category: 155 null or empty values
# category
# Baking                         369
# #Missing                       155
# Beer Wine Spirits               90
# Snacks                          75
# Candy & Sweets                  71
# Beverages                       63
# Magazines                       44
# Health & Wellness               44
# Breakfast & Cereal              40
# Grocery                         39
# Dairy                           33
# Condiments & Sauces             27
# Frozen                          24
# Personal Care                   20
# Baby                            18
# Canned Goods & Soups            12
# Beauty                           9
# Beauty & Personal Care           6
# Deli                             6
# Cleaning & Home Improvement      6
# Household                        5
# Bread & Bakery                   5
# Dairy & Refrigerated             5
# Outdoor                          1
# dtype: int64
#
# ********************
# cpgRef
# ********************
# cpgRef: 2 unique values out of 1167
# cpgRef: 0 null or empty values
# cpgRef
# Cogs    1020
# Cpgs     147
# dtype: int64
#
# ********************
# name
# ********************
# name: 1156 unique values out of 1167
# name: 0 null or empty values
# name
# ONE A DAY® WOMENS            2
# Sierra Mist                  2
# Caleb's Kola                 2
# Health Magazine              2
# Huggies                      2
#                             ..
# LOVE HOME AND PLANET         1
# Lance                        1
# LandShark                    1
# Late July                    1
# test brand @1613158231643    1
# Length: 1156, dtype: int64
#
# ********************
# topBrand
# ********************
# topBrand: 2 unique values out of 1167
# topBrand: 612 null or empty values
# topBrand
# #Missing    612
# 0.0         524
# 1.0          31
# dtype: int64
#
# ********************
# brandCode
# ********************
# brandCode: 897 unique values out of 1167
# brandCode: 269 null or empty values
# brandCode
# #Missing                         234
#                                   35
# HUGGIES                            2
# GOODNITES                          2
# TEST BRANDCODE @1598813526686      1
#                                 ...
# KJELDSEN                           1
# KLEENEX                            1
# KLONDIKE                           1
# KNORR                              1
# ZUMBIDA                            1
# Length: 898, dtype: int64

# %%
# Check category hierarchy
dim_brands.fillna('#Missing').groupby(['categoryCode', 'category']).size()
# Out:
# categoryCode                   category
# #Missing                       #Missing                       155
#                                Baby                            11
#                                Baking                          10
#                                Beauty                           9
#                                Beauty & Personal Care           6
#                                Beer Wine Spirits               59
#                                Beverages                       62
#                                Breakfast & Cereal              40
#                                Canned Goods & Soups            12
#                                Condiments & Sauces             27
#                                Dairy                           33
#                                Deli                             6
#                                Frozen                          23
#                                Grocery                         28
#                                Health & Wellness               30
#                                Household                        5
#                                Magazines                       43
#                                Personal Care                   16
#                                Snacks                          75
# BABY                           Baby                             7
# BAKING                         Baking                         359
# BEER_WINE_SPIRITS              Beer Wine Spirits               31
# BEVERAGES                      Beverages                        1
# BREAD_AND_BAKERY               Bread & Bakery                   5
# CANDY_AND_SWEETS               Candy & Sweets                  71
# CLEANING_AND_HOME_IMPROVEMENT  Cleaning & Home Improvement      6
# DAIRY_AND_REFRIGERATED         Dairy & Refrigerated             5
# FROZEN                         Frozen                           1
# GROCERY                        Grocery                         11
# HEALTHY_AND_WELLNESS           Health & Wellness               14
# MAGAZINES                      Magazines                        1
# OUTDOOR                        Outdoor                          1
# PERSONAL_CARE                  Personal Care                    4
# dtype: int64

# %%
# Check brand hierarchy
dim_brands.fillna('#Missing').groupby(['brandCode', 'name']).size()
# Out:
# brandCode        name
#                  Baked!                                      1
#                  Coors Banquet                               1
#                  Cracker Barrel Macaroni & Cheese Dinners    1
#                  DOVE MEN+CARE                               1
#                  Gevalia Iced Coffee                         1
#                                                             ..
# YOPLAIT GO-GURT  Yoplait® Go-GURT®                           1
# YQ YOPLAIT       YQ by Yoplait®                              1
# YUBAN            Yuban Coffee                                1
# ZIMA             Zima                                        1
# ZUMBIDA          Zumbida                                     1
# Length: 1166, dtype: int64

# %% [markdown]
# ## Findings for dim_brands
# - `brandId` is unique.
# - `brandName` appears to have junk values. More investigation required.
# - `category`, `brandCode`, and `topBrand` have many missing values.
# - Category hierarchy is consistent.
# - Brand hierarchy needs more investigation.

# %% [markdown]
# # dim_users

# %%
dim_users.head()
# Out:
#                      userId  active         createdDateTime  \
# 0  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 1  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 2  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 3  5ff1e1eacfcf6c399c274ae6    True 2021-01-03 15:25:30.554
# 4  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
#
#         lastLoginDateTime      role signUpSource state
# 0 2021-01-03 15:25:37.858  consumer        Email    WI
# 1 2021-01-03 15:25:37.858  consumer        Email    WI
# 2 2021-01-03 15:25:37.858  consumer        Email    WI
# 3 2021-01-03 15:25:30.597  consumer        Email    WI
# 4 2021-01-03 15:25:37.858  consumer        Email    WI

# %%
dim_users_cols = {
    'id_columns': ['userId'],
    'varchar_columns': ['active', 'role', 'signUpSource', 'state'],
    'numeric_columns': ['createdDateTime', 'lastLoginDateTime']
}

all_column_checks(dim_users, dim_users_cols)
# Out:
# ********************
# userId
# ********************
# userId: 212 unique values out of 495
# userId: 0 null or empty values
# userId is not unique
#
# ********************
# active
# ********************
# active: 2 unique values out of 495
# active: 0 null or empty values
# active
# True     494
# False      1
# dtype: int64
#
# ********************
# role
# ********************
# role: 2 unique values out of 495
# role: 0 null or empty values
# role
# consumer       413
# fetch-staff     82
# dtype: int64
#
# ********************
# signUpSource
# ********************
# signUpSource: 2 unique values out of 495
# signUpSource: 48 null or empty values
# signUpSource
# Email       443
# #Missing     48
# Google        4
# dtype: int64
#
# ********************
# state
# ********************
# state: 8 unique values out of 495
# state: 56 null or empty values
# state
# WI          396
# #Missing     56
# NH           20
# AL           12
# OH            5
# IL            3
# CO            1
# KY            1
# SC            1
# dtype: int64
#
# ********************
# createdDateTime
# ********************
# createdDateTime: 212 unique values out of 495
# createdDateTime: 0 null or empty values
# count                              495
# mean     2020-08-06 01:34:47.878830592
# min         2014-12-19 14:21:22.381000
# 25%      2021-01-04 19:30:17.483500032
# 50%      2021-01-13 20:19:38.720999936
# 75%      2021-01-25 17:31:59.408999936
# max         2021-02-12 14:11:06.240000
# Name: createdDateTime, dtype: object
#
# ********************
# lastLoginDateTime
# ********************
# lastLoginDateTime: 172 unique values out of 495
# lastLoginDateTime: 62 null or empty values
# count                              433
# mean     2021-01-23 07:48:00.578216960
# min         2018-05-07 17:23:40.003000
# 25%         2021-01-08 18:14:53.928000
# 50%      2021-01-21 13:57:48.697999872
# 75%      2021-02-03 15:34:11.043000064
# max         2021-03-05 16:52:23.204000
# Name: lastLoginDateTime, dtype: object

# %%
date_order_check(dim_users, 'createdDateTime', 'lastLoginDateTime')
# Out:
# 0 records with lastLoginDateTime before createdDateTime

# %%
id_column_checks(dim_users.drop_duplicates(), 'userId')
# Out:
# ********************
# userId
# ********************
# userId: 212 unique values out of 212
# userId: 0 null or empty values
# userId is unique

# %% [markdown]
# ## Findings for dim_users
# - `userId` is not unique. However, `userId` is unique in the deduplicated dataset (i.e. it contains perfect duplicates)
# - `role` contains values other than "consumer", which contradicts the data dictionary
# - `signUpSource` is not in the data dictionary
# - `signUpSource`, `state`, and `lastLoginDateTime` contain several missing values
# - `lastLoginDateTime` is consistent with `createdDateTime` whenever it is not missing
# - The earliest `createdDateTime` is in 2014, which is long before most values

# %% [markdown]
# # fct_receipts

# %%
fact_receipts.head()
# Out:
#                   receiptId  bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
# 3  5ff1e1ee0a7214ada100056f                5.0
# 4  5ff1e1d20a7214ada1000561                5.0
#
#                              bonusPointsEarnedReason      createDateTime  \
# 0  Receipt number 2 completed, bonus point schedu... 2021-01-03 15:25:31
# 1  Receipt number 5 completed, bonus point schedu... 2021-01-03 15:24:43
# 2                         All-receipts receipt bonus 2021-01-03 15:25:37
# 3                         All-receipts receipt bonus 2021-01-03 15:25:34
# 4                         All-receipts receipt bonus 2021-01-03 15:25:06
#
#       scannedDateTime    finishedDateTime      modifyDateTime  \
# 0 2021-01-03 15:25:31 2021-01-03 15:25:31 2021-01-03 15:25:36
# 1 2021-01-03 15:24:43 2021-01-03 15:24:43 2021-01-03 15:24:48
# 2 2021-01-03 15:25:37                 NaT 2021-01-03 15:25:42
# 3 2021-01-03 15:25:34 2021-01-03 15:25:34 2021-01-03 15:25:39
# 4 2021-01-03 15:25:06 2021-01-03 15:25:11 2021-01-03 15:25:11
#
#   pointsAwardedDateTime  pointsEarned    purchaseDateTime  purchasedItemCount  \
# 0   2021-01-03 15:25:31         500.0 2021-01-03 00:00:00                 5.0
# 1   2021-01-03 15:24:43         150.0 2021-01-02 15:24:43                 2.0
# 2                   NaT           5.0 2021-01-03 00:00:00                 1.0
# 3   2021-01-03 15:25:34           5.0 2021-01-03 00:00:00                 4.0
# 4   2021-01-03 15:25:06           5.0 2021-01-02 15:25:06                 2.0
#
#   rewardsReceiptStatus  totalSpent                    userId
# 0             FINISHED        26.0  5ff1e1eacfcf6c399c274ae6
# 1             FINISHED        11.0  5ff1e194b6a9d73a3a9f1052
# 2             REJECTED        10.0  5ff1e1f1cfcf6c399c274b0b
# 3             FINISHED        28.0  5ff1e1eacfcf6c399c274ae6
# 4             FINISHED         1.0  5ff1e194b6a9d73a3a9f1052

# %%
fact_receipts_cols = {
    'id_columns': ['receiptId', 'userId'],
    'varchar_columns': ['bonusPointsEarnedReason', 'rewardsReceiptStatus'],
    'numeric_columns': ['bonusPointsEarned', 'createDateTime', 'scannedDateTime', 'finishedDateTime', 'modifyDateTime', 'pointsAwardedDateTime', 'pointsEarned', 'purchaseDateTime', 'purchasedItemCount', 'totalSpent']
}

all_column_checks(fact_receipts, fact_receipts_cols)
# Out:
# ********************
# receiptId
# ********************
# receiptId: 1119 unique values out of 1119
# receiptId: 0 null or empty values
# receiptId is unique
#
# ********************
# userId
# ********************
# userId: 258 unique values out of 1119
# userId: 0 null or empty values
# userId is not unique
#
# ********************
# bonusPointsEarnedReason
# ********************
# bonusPointsEarnedReason: 9 unique values out of 1119
# bonusPointsEarnedReason: 575 null or empty values
# bonusPointsEarnedReason
# #Missing                                                                               575
# All-receipts receipt bonus                                                             183
# Receipt number 1 completed, bonus point schedule DEFAULT (5cefdcacf3693e0b50e83a36)    119
# COMPLETE_NONPARTNER_RECEIPT                                                             71
# COMPLETE_PARTNER_RECEIPT                                                                39
# Receipt number 3 completed, bonus point schedule DEFAULT (5cefdcacf3693e0b50e83a36)     31
# Receipt number 2 completed, bonus point schedule DEFAULT (5cefdcacf3693e0b50e83a36)     30
# Receipt number 5 completed, bonus point schedule DEFAULT (5cefdcacf3693e0b50e83a36)     27
# Receipt number 4 completed, bonus point schedule DEFAULT (5cefdcacf3693e0b50e83a36)     26
# Receipt number 6 completed, bonus point schedule DEFAULT (5cefdcacf3693e0b50e83a36)     18
# dtype: int64
#
# ********************
# rewardsReceiptStatus
# ********************
# rewardsReceiptStatus: 5 unique values out of 1119
# rewardsReceiptStatus: 0 null or empty values
# rewardsReceiptStatus
# FINISHED     518
# SUBMITTED    434
# REJECTED      71
# PENDING       50
# FLAGGED       46
# dtype: int64
#
# ********************
# bonusPointsEarned
# ********************
# bonusPointsEarned: 12 unique values out of 1119
# bonusPointsEarned: 575 null or empty values
# count    544.000000
# mean     238.893382
# std      299.091731
# min        5.000000
# 25%        5.000000
# 50%       45.000000
# 75%      500.000000
# max      750.000000
# Name: bonusPointsEarned, dtype: float64
#
# ********************
# createDateTime
# ********************
# createDateTime: 1107 unique values out of 1119
# createDateTime: 0 null or empty values
# count                             1119
# mean     2021-01-28 02:09:41.600271616
# min                2020-10-30 20:17:59
# 25%      2021-01-14 19:13:03.690499840
# 50%                2021-01-29 17:18:22
# 75%      2021-02-07 13:20:13.736999936
# max         2021-03-01 23:17:34.772000
# Name: createDateTime, dtype: object
#
# ********************
# scannedDateTime
# ********************
# scannedDateTime: 1107 unique values out of 1119
# scannedDateTime: 0 null or empty values
# count                             1119
# mean     2021-01-28 02:09:41.600272384
# min                2020-10-30 20:17:59
# 25%      2021-01-14 19:13:03.690499840
# 50%                2021-01-29 17:18:22
# 75%      2021-02-07 13:20:13.736999936
# max         2021-03-01 23:17:34.772000
# Name: scannedDateTime, dtype: object
#
# ********************
# finishedDateTime
# ********************
# finishedDateTime: 553 unique values out of 1119
# finishedDateTime: 551 null or empty values
# count                              568
# mean     2021-01-19 12:10:05.020589568
# min                2021-01-03 15:24:10
# 25%         2021-01-08 21:22:42.500000
# 50%         2021-01-19 21:13:57.500000
# 75%         2021-01-27 17:42:13.500000
# max                2021-02-26 22:36:25
# Name: finishedDateTime, dtype: object
#
# ********************
# modifyDateTime
# ********************
# modifyDateTime: 1104 unique values out of 1119
# modifyDateTime: 0 null or empty values
# count                             1119
# mean     2021-01-28 15:14:28.703043840
# min                2021-01-03 15:24:10
# 25%         2021-01-14 21:32:25.500000
# 50%                2021-01-29 17:18:47
# 75%      2021-02-07 13:20:13.736999936
# max         2021-03-01 23:17:34.772000
# Name: modifyDateTime, dtype: object
#
# ********************
# pointsAwardedDateTime
# ********************
# pointsAwardedDateTime: 523 unique values out of 1119
# pointsAwardedDateTime: 582 null or empty values
# count                              537
# mean     2021-01-18 05:42:47.657355776
# min                2020-10-30 20:18:00
# 25%                2021-01-07 18:15:47
# 50%                2021-01-19 20:54:02
# 75%                2021-01-27 01:12:24
# max                2021-02-26 22:36:25
# Name: pointsAwardedDateTime, dtype: object
#
# ********************
# pointsEarned
# ********************
# pointsEarned: 119 unique values out of 1119
# pointsEarned: 510 null or empty values
# count      609.000000
# mean       585.962890
# std       1357.166947
# min          0.000000
# 25%          5.000000
# 50%        150.000000
# 75%        750.000000
# max      10199.800000
# Name: pointsEarned, dtype: float64
#
# ********************
# purchaseDateTime
# ********************
# purchaseDateTime: 358 unique values out of 1119
# purchaseDateTime: 448 null or empty values
# count                              671
# mean     2020-12-21 10:48:45.994038784
# min                2017-10-30 00:00:00
# 25%                2021-01-05 00:00:00
# 50%                2021-01-13 15:18:59
# 75%                2021-01-26 01:12:58
# max                2021-03-08 17:37:13
# Name: purchaseDateTime, dtype: object
#
# ********************
# purchasedItemCount
# ********************
# purchasedItemCount: 50 unique values out of 1119
# purchasedItemCount: 484 null or empty values
# count    635.00000
# mean      14.75748
# std       61.13424
# min        0.00000
# 25%        1.00000
# 50%        2.00000
# 75%        5.00000
# max      689.00000
# Name: purchasedItemCount, dtype: float64
#
# ********************
# totalSpent
# ********************
# totalSpent: 94 unique values out of 1119
# totalSpent: 435 null or empty values
# count     684.000000
# mean       77.796857
# std       347.110349
# min         0.000000
# 25%         1.000000
# 50%        18.200000
# 75%        34.960000
# max      4721.950000
# Name: totalSpent, dtype: float64

# %%
fact_receipts['hasBonusPointsEarned'] = ~fact_receipts['bonusPointsEarned'].isnull()
fact_receipts['hasBonusPointsEarnedReason'] = ~fact_receipts['bonusPointsEarnedReason'].isnull()
fact_receipts.groupby(['hasBonusPointsEarned', 'hasBonusPointsEarnedReason']).size()
# Out:
# hasBonusPointsEarned  hasBonusPointsEarnedReason
# False                 False                         575
# True                  True                          544
# dtype: int64

# %%
fact_receipts['hasPointsEarned'] = ~fact_receipts['pointsEarned'].isnull()
fact_receipts['hasPointsAwardedDateTime'] = ~fact_receipts['pointsAwardedDateTime'].isnull()
fact_receipts.groupby(['hasPointsEarned', 'hasPointsAwardedDateTime']).size()
# Out:
# hasPointsEarned  hasPointsAwardedDateTime
# False            False                       510
# True             False                        72
#                  True                        537
# dtype: int64

# %%
date_order_check(fact_receipts, 'createDateTime', 'modifyDateTime')
date_order_check(fact_receipts, 'createDateTime', 'scannedDateTime')
date_order_check(fact_receipts, 'scannedDateTime', 'finishedDateTime')
date_order_check(fact_receipts, 'createDateTime', 'purchaseDateTime')
date_order_check(fact_receipts, 'purchaseDateTime', 'pointsAwardedDateTime')
# Out:
# 0 records with modifyDateTime before createDateTime
# 0 records with scannedDateTime before createDateTime
# 0 records with finishedDateTime before scannedDateTime
# 628 records with purchaseDateTime before createDateTime
# 7 records with pointsAwardedDateTime before purchaseDateTime

# %%
print(f"{sum(fact_receipts['finishedDateTime'] < fact_receipts['createDateTime'])} records with lastLoginDateTime before createdDateTime")
# Out:
# 0 records with lastLoginDateTime before createdDateTime

# %% [markdown]
# ## Findings for fact_receipts
# - `receiptId` is unique
# - `'hasBonusPointsEarned` and `hasBonusPointsEarnedReason` are consistent: they are either both null or both non-null
# - `bonusPointsEarned` has a reasonable distribution (positive, between 5 and 750)
# - `finishedDateTime` contains several missing values, which may be valid if the transactions did not finish.
# - `purchaseDateTime` contains several missing values, which may be valid if the transactions did not result in a purchase.
# - `purchaseDateTime` often occurs before `createDateTime`. On closer inspection, `purchaseDateTime` often contains only the date, not the date/time.
# - `totalSpent` has a reasonable distribution (between $0 and $4,721.95)
# - 7 records with `pointsAwardedDateTime` before `purchaseDateTime`. Should this be possible?

# %% [markdown]
# # fct_receipt_items

# %%
fact_receipt_items.head()
# Out:
#                           receiptItemId                 receiptId  \
# 0  80bab23e-218c-4445-ab4e-538e430f2671  5ff1e1eb0a720f0523000575
# 1  76cf43a0-0052-4c48-b76b-5ce1538ef076  5ff1e1bb0a720f052300056b
# 1  4eba9404-308f-4729-9bca-78449262e3b1  5ff1e1bb0a720f052300056b
# 2  cd94aab2-c8c5-448e-8278-437d6af4a3e8  5ff1e1f10a720f052300057a
# 3  f6ea8b25-6a48-4e87-9466-dabe53d54d1a  5ff1e1ee0a7214ada100056f
#
#         barcode                                        description  \
# 0          4011                                     ITEM NOT FOUND
# 1          4011                                     ITEM NOT FOUND
# 1  028400642255  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...
# 2          None                                               None
# 3          4011                                     ITEM NOT FOUND
#
#    finalPrice  itemPrice needsFetchReview partnerItemId  \
# 0        26.0       26.0            False             1
# 1         1.0        1.0             None             1
# 1        10.0       10.0             True             2
# 2         NaN        NaN            False             1
# 3        28.0       28.0            False             1
#
#    preventTargetGapPoints  quantityPurchased  ... itemNumber  \
# 0                     1.0                5.0  ...       None
# 1                     NaN                1.0  ...       None
# 1                     1.0                1.0  ...       None
# 2                     1.0                NaN  ...       None
# 3                     1.0                4.0  ...       None
#
#   originalMetaBriteQuantityPurchased  pointsEarned  targetPrice  \
# 0                                NaN          None          NaN
# 1                                NaN          None          NaN
# 1                                NaN          None          NaN
# 2                                NaN          None          NaN
# 3                                NaN          None          NaN
#
#   competitiveProduct originalFinalPrice originalMetaBriteItemPrice deleted  \
# 0               None                NaN                        NaN    None
# 1               None                NaN                        NaN    None
# 1               None                NaN                        NaN    None
# 2               None                NaN                        NaN    None
# 3               None                NaN                        NaN    None
#
#   priceAfterCoupon metabriteCampaignId
# 0              NaN                None
# 1              NaN                None
# 1              NaN                None
# 2              NaN                None
# 3              NaN                None
#
# [5 rows x 36 columns]

# %%
fact_receipt_items_cols = {
    'id_columns': ['receiptItemId', 'receiptId', 'partnerItemId'],
    'varchar_columns': ['barcode', 'description', 'brandCode', 'rewardsGroup', 'deleted'],
    'numeric_columns': ['finalPrice', 'itemPrice', 'pointsEarned']
}

all_column_checks(fact_receipt_items, fact_receipt_items_cols)
# Out:
# ********************
# receiptItemId
# ********************
# receiptItemId: 6941 unique values out of 6941
# receiptItemId: 0 null or empty values
# receiptItemId is unique
#
# ********************
# receiptId
# ********************
# receiptId: 679 unique values out of 6941
# receiptId: 0 null or empty values
# receiptId is not unique
#
# ********************
# partnerItemId
# ********************
# partnerItemId: 916 unique values out of 6941
# partnerItemId: 0 null or empty values
# partnerItemId is not unique
#
# ********************
# barcode
# ********************
# barcode: 568 unique values out of 6941
# barcode: 3851 null or empty values
# barcode
# #Missing        3851
# 4011             177
# 036000320893      92
# 034100573065      90
# 036000391718      87
#                 ...
# 043000013229       1
# 043000012871       1
# 043000004944       1
# 043000003596       1
# B08DQDHR2S         1
# Length: 569, dtype: int64
#
# ********************
# description
# ********************
# description: 1889 unique values out of 6941
# description: 381 null or empty values
# description
# #Missing                                                                                                        381
# ITEM NOT FOUND                                                                                                  173
# KLARBRUNN 12PK 12 FL OZ                                                                                         120
# HUGGIES SIMPLY CLEAN PREMOISTENED WIPE FRAGRANCE FREE BAG 216 COUNT                                              92
# MILLER LITE 24 PACK 12OZ CAN                                                                                     90
#                                                                                                                ...
# DOVE MEN PLUS CARE AQUA IMPACT WASH SOAP TOTTLE SP 19.8 OZ                                                        1
# DOVE MEN PLUS CARE ANTIPERSPIRANT EXTRA FRESH 48 HOUR PROTECTION PLASTIC WRAPPED PLASTIC CONTAINER SP 2.7 OZ      1
# DORITOS TORTILLA CHIP RANCHERITOS BAG 2.75 OZ                                                                     1
# DORITOS TORTILLA CHIP COOL RANCH BAG 7.625 OZ                                                                     1
# HVRCUPSORIGINAI 1                                                                                                 1
# Length: 1890, dtype: int64
#
# ********************
# brandCode
# ********************
# brandCode: 227 unique values out of 6941
# brandCode: 4341 null or empty values
# brandCode
# #Missing           4341
# HY-VEE              291
# BEN AND JERRYS      180
# PEPSI                93
# KROGER               89
#                    ...
# NATURE VALLEY         1
# GERBER                1
# SIMPLY POTATOES       1
# GERM-X                1
# EGGO                  1
# Length: 228, dtype: int64
#
# ********************
# rewardsGroup
# ********************
# rewardsGroup: 182 unique values out of 6941
# rewardsGroup: 5210 null or empty values
# rewardsGroup
# #Missing                                                            5210
# BEN AND JERRYS ICE CREAM                                             181
# HUGGIES ONE AND DONE SIMPLY CLEAN BABY WIPES 200 COUNT OR LARGER      92
# MILLER LITE 24 PACK                                                   90
# KLEENEX TRUSTED CARE FACIAL TISSUES 120 - 179 COUNT, 8 PACK           87
#                                                                     ...
# AIR WICK ROOM SPRAYS                                                   1
# BREYERS ICE CREAM AND FROZEN DESSERTS                                  1
# KLEENEX TRUSTED CARE FACIAL TISSUES 1 - 59 COUNT, 8 PACK               1
# CAPRI SUN BEVERAGE DRINK                                               1
# KLEENEX WET WIPES                                                      1
# Length: 183, dtype: int64
#
# ********************
# deleted
# ********************
# deleted: 1 unique values out of 6941
# deleted: 6932 null or empty values
# deleted
# #Missing    6932
# True           9
# dtype: int64
#
# ********************
# finalPrice
# ********************
# finalPrice: 823 unique values out of 6941
# finalPrice: 174 null or empty values
# count    6767.000000
# mean        7.871661
# std        14.656776
# min         0.000000
# 25%         2.290000
# 50%         4.280000
# 75%         9.990000
# max       441.580000
# Name: finalPrice, dtype: float64
#
# ********************
# itemPrice
# ********************
# itemPrice: 823 unique values out of 6941
# itemPrice: 174 null or empty values
# count    6767.000000
# mean        7.872178
# std        14.656623
# min         0.000000
# 25%         2.290000
# 50%         4.280000
# 75%         9.990000
# max       441.580000
# Name: itemPrice, dtype: float64
#
# ********************
# pointsEarned
# ********************
# pointsEarned: 277 unique values out of 6941
# pointsEarned: 6014 null or empty values
# count      927
# unique     277
# top       50.0
# freq       123
# Name: pointsEarned, dtype: object

# %% [markdown]
# ## Findings for fct_receipt_items
# - `receiptItemId` is unique
# - `barcode` has several missing values, and also a lot of values of "4011" which are inconsistent with other values in the column
# - `description` has many missing values and several more "ITEM NOT FOUND" values
# - `brandCode`, `rewardsGroup` and `pointsEarned` are missing for the majority of records
# - `deleted` looks reasonable, assuming blanks correspond to False
# - `itemPrice` and `finalPrice` have reasonable distributions (between $0 and $441.58)

# %% [markdown]
# # Foreign key referential integrity

# %%
referential_integrity_check(fact_receipts, 'userId', dim_users['userId'])
# Out:
# 148 out of 1119 orphaned values of userId

# %%
referential_integrity_check(fact_receipt_items, 'receiptId', fact_receipts['receiptId'])
# Out:
# 0 out of 6941 orphaned values of receiptId

# %%
referential_integrity_check(fact_receipt_items, 'barcode', dim_brands['barcode'])
# Out:
# 6941 out of 6941 orphaned values of barcode

# %%
referential_integrity_check(fact_receipt_items, 'brandCode', dim_brands['brandCode'])
# Out:
# 1971 out of 6941 orphaned values of brandCode

# %% [markdown]
# ## Findings for foreign key referential integrity:
# - There are many orphaned `brandCode` values in the receipt items table. This is concerning because it affects the brand-level analysis in the other notebook. The data dictionary says: that `brandCode` is a "string that corresponds with the brand column in a partner product file", so the orphaned values may be unexpected.
# - There are 148 orphaned `userId` values in the receipts table.
# - The referential integrity of `receiptId` in the receipt items table was ensured by the data pipeline.
